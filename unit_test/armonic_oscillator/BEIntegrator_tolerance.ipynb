# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
be_001_e2_df = pd.read_csv('tolerance_analysis/be/solution_001_e-2.csv')
be_001_e2_error = np.sqrt((be_001_e2_df['abs_error']**2).sum())
be_0001_e2_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-2.csv')
be_0001_e2_error = np.sqrt((be_0001_e2_df['abs_error']**2).sum())
be_00001_e2_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-2.csv')
be_00001_e2_error = np.sqrt((be_00001_e2_df['abs_error']**2).sum())
be_000001_e2_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-2.csv')
be_000001_e2_error = np.sqrt((be_000001_e2_df['abs_error']**2).sum())

be_001_e3_df = pd.read_csv('tolerance_analysis/be/solution_001_e-3.csv')
be_001_e3_error = np.sqrt((be_001_e3_df['abs_error']**2).sum())
be_0001_e3_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-3.csv')
be_0001_e3_error = np.sqrt((be_0001_e3_df['abs_error']**2).sum())
be_00001_e3_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-3.csv')
be_00001_e3_error = np.sqrt((be_00001_e3_df['abs_error']**2).sum())
be_000001_e3_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-3.csv')
be_000001_e3_error = np.sqrt((be_000001_e3_df['abs_error']**2).sum())

be_001_e4_df = pd.read_csv('tolerance_analysis/be/solution_001_e-4.csv')
be_001_e4_error = np.sqrt((be_001_e4_df['abs_error']**2).sum())
be_0001_e4_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-4.csv')
be_0001_e4_error = np.sqrt((be_0001_e4_df['abs_error']**2).sum())
be_00001_e4_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-4.csv')
be_00001_e4_error = np.sqrt((be_00001_e4_df['abs_error']**2).sum())
be_000001_e4_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-4.csv')
be_000001_e4_error = np.sqrt((be_000001_e4_df['abs_error']**2).sum())

be_001_e5_df = pd.read_csv('tolerance_analysis/be/solution_001_e-5.csv')
be_001_e5_error = np.sqrt((be_001_e5_df['abs_error']**2).sum())
be_0001_e5_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-5.csv')
be_0001_e5_error = np.sqrt((be_0001_e5_df['abs_error']**2).sum())
be_00001_e5_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-5.csv')
be_00001_e5_error = np.sqrt((be_00001_e5_df['abs_error']**2).sum())
be_000001_e5_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-5.csv')
be_000001_e5_error = np.sqrt((be_000001_e5_df['abs_error']**2).sum())

be_001_e6_df = pd.read_csv('tolerance_analysis/be/solution_001_e-6.csv')
be_001_e6_error = np.sqrt((be_001_e6_df['abs_error']**2).sum())
be_0001_e6_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-6.csv')
be_0001_e6_error = np.sqrt((be_0001_e6_df['abs_error']**2).sum())
be_00001_e6_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-6.csv')
be_00001_e6_error = np.sqrt((be_00001_e6_df['abs_error']**2).sum())
be_000001_e6_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-6.csv')
be_000001_e6_error = np.sqrt((be_000001_e6_df['abs_error']**2).sum())

be_001_e7_df = pd.read_csv('tolerance_analysis/be/solution_001_e-7.csv')
be_001_e7_error = np.sqrt((be_001_e7_df['abs_error']**2).sum())
be_0001_e7_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-7.csv')
be_0001_e7_error = np.sqrt((be_0001_e7_df['abs_error']**2).sum())
be_00001_e7_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-7.csv')
be_00001_e7_error = np.sqrt((be_00001_e7_df['abs_error']**2).sum())
be_000001_e7_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-7.csv')
be_000001_e7_error = np.sqrt((be_000001_e7_df['abs_error']**2).sum())

be_001_e8_df = pd.read_csv('tolerance_analysis/be/solution_001_e-8.csv')
be_001_e8_error = np.sqrt((be_001_e8_df['abs_error']**2).sum())
be_0001_e8_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-8.csv')
be_0001_e8_error = np.sqrt((be_0001_e8_df['abs_error']**2).sum())
be_00001_e8_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-8.csv')
be_00001_e8_error = np.sqrt((be_00001_e8_df['abs_error']**2).sum())
be_000001_e8_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-8.csv')
be_000001_e8_error = np.sqrt((be_000001_e8_df['abs_error']**2).sum())

be_001_e9_df = pd.read_csv('tolerance_analysis/be/solution_001_e-9.csv')
be_001_e9_error = np.sqrt((be_001_e9_df['abs_error']**2).sum())
be_0001_e9_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-9.csv')
be_0001_e9_error = np.sqrt((be_0001_e9_df['abs_error']**2).sum())
be_00001_e9_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-9.csv')
be_00001_e9_error = np.sqrt((be_00001_e9_df['abs_error']**2).sum())
be_000001_e9_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-9.csv')
be_000001_e9_error = np.sqrt((be_000001_e9_df['abs_error']**2).sum())

be_0001_e10_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-10.csv')
be_0001_e10_error = np.sqrt((be_0001_e10_df['abs_error']**2).sum())
be_00001_e10_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-10.csv')
be_00001_e10_error = np.sqrt((be_00001_e10_df['abs_error']**2).sum())
be_000001_e10_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-10.csv')
be_000001_e10_error = np.sqrt((be_000001_e10_df['abs_error']**2).sum())

be_0001_e11_df = pd.read_csv('tolerance_analysis/be/solution_0001_e-11.csv')
be_0001_e11_error = np.sqrt((be_0001_e11_df['abs_error']**2).sum())
be_00001_e11_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-11.csv')
be_00001_e11_error = np.sqrt((be_00001_e11_df['abs_error']**2).sum())
be_000001_e11_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-11.csv')
be_000001_e11_error = np.sqrt((be_000001_e11_df['abs_error']**2).sum())

be_00001_e12_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-12.csv')
be_00001_e12_error = np.sqrt((be_00001_e12_df['abs_error']**2).sum())
be_000001_e12_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-12.csv')
be_000001_e12_error = np.sqrt((be_000001_e12_df['abs_error']**2).sum())

be_00001_e13_df = pd.read_csv('tolerance_analysis/be/solution_00001_e-13.csv')
be_00001_e13_error = np.sqrt((be_00001_e13_df['abs_error']**2).sum())
be_000001_e13_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-13.csv')
be_000001_e13_error = np.sqrt((be_000001_e13_df['abs_error']**2).sum())

be_000001_e14_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-14.csv')
be_000001_e14_error = np.sqrt((be_000001_e14_df['abs_error']**2).sum())

be_000001_e15_df = pd.read_csv('tolerance_analysis/be/solution_000001_e-15.csv')
be_000001_e15_error = np.sqrt((be_000001_e15_df['abs_error']**2).sum())


eps_001 = [1.e-2, 1.e-3, 1.e-4, 1.e-5, 1.e-6, 1.e-7, 1.e-8, 1.e-9]
be_001_error = [be_001_e2_error,be_001_e3_error,be_001_e4_error,be_001_e5_error,be_001_e6_error,be_001_e7_error,be_001_e8_error,be_001_e9_error]
eps_0001 = [1.e-2, 1.e-3, 1.e-4, 1.e-5, 1.e-6, 1.e-7, 1.e-8, 1.e-9, 1.e-10, 1.e-11]
be_0001_error = [be_0001_e2_error,be_0001_e3_error,be_0001_e4_error,be_0001_e5_error,be_0001_e6_error,be_0001_e7_error,be_0001_e8_error,be_0001_e9_error,be_0001_e10_error,be_0001_e11_error]
eps_00001 = [1.e-2, 1.e-3, 1.e-4, 1.e-5, 1.e-6, 1.e-7, 1.e-8, 1.e-9, 1.e-10, 1.e-11, 1.e-12, 1.e-13]
be_00001_error = [be_00001_e2_error,be_00001_e3_error,be_00001_e4_error,be_00001_e5_error,be_00001_e6_error,be_00001_e7_error,be_00001_e8_error,be_00001_e9_error,be_00001_e10_error,be_00001_e11_error,be_00001_e12_error,be_00001_e13_error]
eps_000001 = [1.e-2, 1.e-3, 1.e-4, 1.e-5, 1.e-6, 1.e-7, 1.e-8, 1.e-9, 1.e-10, 1.e-11, 1.e-12, 1.e-13, 1.e-14, 1.e-15]
be_000001_error = [be_000001_e2_error,be_000001_e3_error,be_000001_e4_error,be_000001_e5_error,be_000001_e6_error,be_000001_e7_error,be_000001_e8_error,be_000001_e9_error,be_000001_e10_error,be_000001_e11_error,be_000001_e12_error,be_000001_e13_error,be_000001_e14_error,be_000001_e15_error]


data_001_df = pd.read_csv('tolerance_analysis/be/data_001.csv')
nsteps_001 = data_001_df['nsteps']
time_001 = data_001_df['time']

data_0001_df = pd.read_csv('tolerance_analysis/be/data_0001.csv')
nsteps_0001 = data_0001_df['nsteps']
time_0001 = data_0001_df['time']

data_00001_df = pd.read_csv('tolerance_analysis/be/data_00001.csv')
nsteps_00001 = data_00001_df['nsteps']
time_00001 = data_00001_df['time']

data_000001_df = pd.read_csv('tolerance_analysis/be/data_000001.csv')
nsteps_000001 = data_000001_df['nsteps']
time_000001 = data_000001_df['time']


# Plot
fig, ax1 = plt.subplots()
ax1.scatter(eps_001, be_001_error, marker='o', color='blue')
ax1.plot(eps_001, be_001_error, color='blue', label='error')
ax1.set_xlabel('tolerance')
ax1.set_ylabel('error')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax2 = ax1.twinx()
ax2.scatter(eps_001, time_001, marker='s', color='black')
ax2.plot(eps_001, time_001, color='black', label='timing')
ax2.set_ylabel('timing (s)')
#ax2.set_yscale('log')
xmin, xmax = plt.xlim()
plt.xlim(xmax, xmin)
plt.title('dt=1.e-2 s')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
handles, labels = [], []
for ax in [ax1, ax2]:
    h, l = ax.get_legend_handles_labels()
    handles.extend(h)
    labels.extend(l)
# Set legend location to 'center left' and place it outside of the plot area
ax1.legend(handles, labels, loc='center left')
plt.show()


# Plot
fig, ax1 = plt.subplots()
ax1.scatter(eps_0001, be_0001_error, marker='o', color='red')
ax1.plot(eps_0001, be_0001_error, color='red', label='error')
ax1.set_xlabel('tolerance')
ax1.set_ylabel('error')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax2 = ax1.twinx()
ax2.scatter(eps_0001, time_0001, marker='s', color='black')
ax2.plot(eps_0001, time_0001, color='black', label='timing')
ax2.set_ylabel('timing (s)')
#ax2.set_yscale('log')
xmin, xmax = plt.xlim()
plt.xlim(xmax, xmin)
plt.title('dt=1.e-3 s')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
handles, labels = [], []
for ax in [ax1, ax2]:
    h, l = ax.get_legend_handles_labels()
    handles.extend(h)
    labels.extend(l)
# Set legend location to 'center left' and place it outside of the plot area
ax1.legend(handles, labels, loc='center left')
plt.show()


# Plot
fig, ax1 = plt.subplots()
ax1.scatter(eps_00001[0:10], be_00001_error[0:10], marker='o', color='green')
ax1.plot(eps_00001[0:10], be_00001_error[0:10], color='green', label='error')
ax1.set_xlabel('tolerance')
ax1.set_ylabel('error')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax2 = ax1.twinx()
ax2.scatter(eps_00001[0:10], time_00001[0:10], marker='s', color='black')
ax2.plot(eps_00001[0:10], time_00001[0:10], color='black', label='timing')
ax2.set_ylabel('timing (s)')
#ax2.set_yscale('log')
xmin, xmax = plt.xlim()
plt.xlim(xmax, xmin)
plt.title('dt=1.e-4 s')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
handles, labels = [], []
for ax in [ax1, ax2]:
    h, l = ax.get_legend_handles_labels()
    handles.extend(h)
    labels.extend(l)
# Set legend location to 'center left' and place it outside of the plot area
ax1.legend(handles, labels, loc='center left')
plt.show()


# Plot
fig, ax1 = plt.subplots()
ax1.scatter(eps_000001[0:11], be_000001_error[0:11], marker='o', color='brown')
ax1.plot(eps_000001[0:11], be_000001_error[0:11], color='brown', label='error')
ax1.set_xlabel('tolerance')
ax1.set_ylabel('error')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax2 = ax1.twinx()
ax2.scatter(eps_000001[0:11], time_000001[0:11], marker='s', color='black')
ax2.plot(eps_000001[0:11], time_000001[0:11], color='black', label='timing')
ax2.set_ylabel('timing (s)')
#ax2.set_yscale('log')
xmin, xmax = plt.xlim()
plt.xlim(xmax, xmin)
plt.title('dt=1.e-5 s')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
handles, labels = [], []
for ax in [ax1, ax2]:
    h, l = ax.get_legend_handles_labels()
    handles.extend(h)
    labels.extend(l)
# Set legend location to 'center left' and place it outside of the plot area
ax1.legend(handles, labels, loc='center left')
plt.show()
